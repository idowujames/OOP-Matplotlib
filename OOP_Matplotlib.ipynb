# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %% [markdown]
# ## Reading in the titanic dataset from bitly

# %%
df = pd.read_csv('http://bit.ly/tcsv19')

df.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#      age  sibsp  parch  ticket      fare    cabin embarked
# 0  29.00      0      0   24160  211.3375       B5        S
# 1   0.92      1      2  113781  151.5500  C22 C26        S
# 2   2.00      1      2  113781  151.5500  C22 C26        S
# 3  30.00      1      2  113781  151.5500  C22 C26        S
# 4  25.00      1      2  113781  151.5500  C22 C26        S

# %%
df.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked'],
#       dtype='object')

# %%
fig,ax = plt.subplots()
_ = ax.plot(np.sort(df['age']), marker='o', markersize=1)

# %% [markdown]
# ### Using the '?' to callup the help documentation for a particular feature

# %%
ax.plot?

# %% [markdown]
# ### Getting the available MAtplotlib backend

# %%
import matplotlib
matplotlib.get_backend()
# Out:
# 'module://matplotlib_inline.backend_inline'

# %% [markdown]
# ## Making a plot

# %% [markdown]
# **First thing to make when drawing a plot is a Figure**

# %%
plt.figure()

# %% [markdown]
# The figure method does not show anything until you start actually drawing something. i.e: Having an Axes(e.g x-axis,y-axis)

# %% [markdown]
# The **subplot** method gives both a **Figure** an **Axes** to draw on

# %%
plt.subplots()
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: >)

# %% [markdown]
# **plt.subplots() returns 2 objects. A Figure object and an Axes(or collection of Axes) object**

# %%
fig, ax = plt.subplots()

# %% [markdown]
# ## Adding data to the figure using a plotting method

# %%
fig, ax = plt.subplots()
_ = ax.plot(np.sort(df['age']), marker='o', markersize=1)

# the unnamed variable is a way of supressing the print statement from the plot output
# it's ths same as writing 'ax.plot(np.sort(df['age']), marker='o', markersize=1);'

# %% [markdown]
# ### Seting labels

# %%
fig, ax = plt.subplots()
ax.plot(np.sort(df['age']), marker='o', markersize=1)
ax.set_xlabel('Passengers')
ax.set_ylabel('Ages')
ax.set_title('Titanic Dataset');

# %% [markdown]
# ### Breaking the Y-axis according to US Census demographics

# %%
fig, ax = plt.subplots()
ax.plot(np.sort(df['age']), marker='o', markersize=1)
ax.set_xlabel('Passengers')
ax.set_ylabel('Ages')
ax.set_yticks([15,25,55,64])
ax.set_yticklabels(['Children','Youth', 'Adults', 'Seniors'])


ax.set_title('Titanic Dataset');

# %% [markdown]
# ## Exercise 1
#
# Plot the Fares using the following labels
# * First Class Suite: 870pounds or $4,350
#
# * First Class Berth: 30pounds or $150
#
# * Second Class: 12pounds or $60
#
# * Third Class: 3 to 8pounds or $40

# %%
df.shape
# Out:
# (1309, 11)

# %%
# Creating the figure and axes
fig, ax = plt.subplots()

# Plotting the fare column
ax.plot(np.sort(df['fare']), marker='o', markersize=5, linestyle="")

# Setting Axis labels and title
ax.set_xlabel('Passengers')
ax.set_ylabel('Fare')
ax.set_yticks([3,12,30,870])
ax.set_yticklabels(['Third Class','Second Class','First Class Berth','First Class Suite'])

ax.set_title('Titanic Dataset');

# %% [markdown]
# As we can see above, the fare classes are squashed together.
# One way of solving this problem is to convert the Y-axis to log scale

# %%
# Creating the figure and axes
fig, ax = plt.subplots()

# Plotting the fare column
ax.plot(np.sort(df['fare']), marker='o', markersize=5, linestyle="")

# Setting Axis labels and title
ax.set_xlabel('Passengers')
ax.set_ylabel('Fare')

ax.set_yscale('log') # This has to be done before customizing the ticks & tick labels
ax.set_yticks([3,12,30,870])
ax.set_yticklabels(['Third Class','Second Class','First Class Berth','First Class Suite'])

ax.set_title('Titanic Dataset');

# %% [markdown]
# ## Making Multiple plots on the same figure

# %%
fig, (ax1,ax2) = plt.subplots(ncols=2) # This works with rows(nrows) also

fig.suptitle('This is the Super Title');

# %%
# For a grid we can't use tuple unpacking so

fig,axes = plt.subplots(nrows=2,ncols=2,constrained_layout=True)

fig.suptitle('This is the Super Title For The Grid');

# %% [markdown]
# #### Plotting Fare and Ages on the same figure

# %%
fig, (ax1,ax2) = plt.subplots(ncols=2, constrained_layout=True)

# Plotting the fare column
ax1.plot(np.sort(df['fare']), marker='o', markersize=5, linestyle="")
ax2.plot(np.sort(df['age']), marker='o', markersize=5, linestyle="")

# Setting Axis labels and title For Fare Plot
ax1.set_xlabel('Passengers')
ax1.set_ylabel('Fare')
ax1.set_yscale('log') # This has to be done before customizing the ticks & tick labels
ax1.set_yticks([3,12,30,870])
ax1.set_yticklabels(['Third Class','Second Class','First Class Berth','First Class Suite'])

# Setting Axis labels and title For Age Plot
ax2.set_xlabel('Passengers')
ax2.set_ylabel('Ages')
ax2.set_yticks([15,25,55,64])
ax2.set_yticklabels(['Children','Youth', 'Adults', 'Seniors'])

fig.suptitle('Titanic Dataset');

# %% [markdown]
# ### Customizing the Grid ratio of the Plots

# %%
fig, (ax1,ax2) = plt.subplots(ncols=2, constrained_layout=True, gridspec_kw={'width_ratios':[3,1]})

# Plotting the fare column
ax1.plot(np.sort(df['fare']), marker='o', markersize=5, linestyle="")
ax2.plot(np.sort(df['age']), marker='o', markersize=5, linestyle="")

# Setting Axis labels and title For Fare Plot
ax1.set_xlabel('Passengers')
ax1.set_ylabel('Fare')
ax1.set_yscale('log') # This has to be done before customizing the ticks & tick labels
ax1.set_yticks([3,12,30,870])
ax1.set_yticklabels(['Third Class','Second Class','First Class Berth','First Class Suite'])

# Setting Axis labels and title For Age Plot
ax2.set_xlabel('Passengers')
ax2.set_ylabel('Ages')
ax2.set_yticks([15,25,55,64])
ax2.set_yticklabels(['Children','Youth', 'Adults', 'Seniors'])

fig.suptitle('Titanic Dataset');
